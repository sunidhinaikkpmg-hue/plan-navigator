# %%
cloud-sql-proxy adv-lighthouse-plnv:us-central1:plnv-project --port 5432

# %%
import psycopg2
import psycopg2
from dotenv import load_dotenv
import os
load_dotenv()

try:
    conn = psycopg2.connect(
        host="127.0.0.1",
        port=5432,
        user="postgres",
        password=os.getenv("DB_PASSWORD"),
        dbname="postgres"
    )

    print("✅ Connected")

    cursor = conn.cursor()
    cursor.execute("SELECT 1;")

    result = cursor.fetchone()
    print("Query result:", result)

    # conn.close()

except Exception as e:
    print("❌ Error:", e)
# Out:
# ✅ Connected
# Query result: (1,)

# %%
import psycopg2
import os

conn = psycopg2.connect(
    host="127.0.0.1",
    port=5432,
    user="postgres",
    password=os.getenv("DB_PASSWORD"),
    dbname="postgres" # Connect to default to see others
)

cursor = conn.cursor()
cursor.execute("SELECT datname FROM pg_database;")
for db in cursor.fetchall():
    print(db[0])
conn.close()
# Out:
# cloudsqladmin
# postgres
# template1
# template0
# PlanNavigator
# helloworld-vector-1778139247365

# %%
pip install dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker
import os

password = os.getenv("DB_PASSWORD")

engine = create_engine(
    f"postgresql+psycopg2://postgres:{password}@127.0.0.1:5432/postgres"
)


SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)

def get_db():
    with SessionLocal() as db:
        yield db

# %%
pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 35.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.4/611.4 kB 28.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
db = next(get_db())

result = db.execute(text("SELECT * FROM plans LIMIT 10"))

for row in result:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 db = next(get_db())
#       3 result = db.execute(text("SELECT * FROM plans LIMIT 10"))
#       5 for row in result:
#
# NameError: name 'get_db' is not defined

# %%
import os
print("DB_HOST", os.getenv("DB_HOST"))
print("DB_PORT", os.getenv("DB_PORT"))
print("DB_USER", os.getenv("DB_USER"))
print("DB_NAME", os.getenv("DB_NAME"))
print("DATABASE_URL", os.getenv("DATABASE_URL"))
# Out:
# DB_HOST None
# DB_PORT None
# DB_USER None
# DB_NAME None
# DATABASE_URL None
